# %% [markdown]
# <a href="https://colab.research.google.com/github/Melges-Rayssa/Codigos_GoogleColab/blob/master/Graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando gráficos em phthon
#
# *   Item da lista

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *
import numpy as np

# %%
x= [1,3,5,7,9]
y= [6,7,8,2,4]

# %%
plt.bar(x,y, label ='Barras', color = 'b')
plt.legend()
plt.show()

# %%
x2= [2,4,6,8,10]
y2= [7,2,4,5,8]

# %%
plt.bar(x,y, label ='Barras', color = 'b')
plt.bar(x2,y2, label = 'Barras2', color = 'y')
plt.legend()
plt.show()

# %%
idades = [13,12,16,22,84,43,23,22,10,9,77,55,49]

# %%
ids = [ x for x in range(len(idades))]

# %%
# bar e a função para fazer graficos de barras
plt.bar(ids, idades)
plt.show()

# %%
bins = [0,5,10,15,20,25,30,35,40,45,50,55,60]

# %%
# hist e a função para fazer histogramas
plt.hist(idades, bins, histtype= 'bar', rwidth = 0.8)
plt.show()

# %%
plt.hist(idades, bins, histtype= 'stepfilled', rwidth= 0.8)
plt.show()

# %%
x = [2,4,6,8,3,7,5,9]
y = [1,2,3,4,5,6,7,8,]

# %%
plt.scatter(x,y, label = 'Pontos', color = 'r', marker = 'o', s = 100)
plt.legend()
plt.show()

# %%
fatias = [6,4,4,10]
atividades = [ ' comer', ' dormir', 'estudar', 'descansar']
colunas = ['c', 'm', 'r', 'k']

# %%
plt.pie(fatias, labels = atividades, colors = colunas, startangle = 90, shadow = True, explode = (0,0.1,0,0))
plt.show()

# %%
x = linspace (3,13,23)
y = x**2

fig = plt.figure()

#definindo os eixos
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y,'r')

axes.set_xlabel1('x')
axes.set_ylabel1('y')
axes.set_title('Gráfico de linha');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-33a9857bc50a> in <module>()
#       7 axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
#       8 axes.plot(x,y,'r')
# ----> 9 axes.set_xlabel1('x')
#      10 axes.set_ylabel1('y')
#      11 axes.set_title('Gráfico de linha');
#
# AttributeError: 'Axes' object has no attribute 'set_xlabel1'

# %%
fig, axes = plt.subplots(nrows= 1, ncols=2)

for ax in axes:
  ax.plot(x,y, 'r')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_title('Título')

fig.tight_layout()

# %%
# arange = array, random = valores randomicos que são valores aleatorios
plt.scatter(np.arange(50), np.random.randn(50))
plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax1.plot(np.random.randn(50), color = 'yellow')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(np.arange(50), np.random.randn(50))
plt.show()

# %%
#grid coloca os quadrinhos
fig, axes = plt.subplots(1,2, figsize=(10,4))

axes[0].plot(x,x**2, x, exp(x))
axes[0].set_title("Escala Padrão")
axes[0].grid(True)

axes[1].plot(x,x**2,x,exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Escala Logaritmica (y)");

# %%
xx = np.linspace(-0,75,1.,100)
n= np.array([0,1,2,3,4,5])

fig,axes = plt.subplots(1,4,figsize=(12,3))

axes[0].scatter(xx , xx + 0.25*randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n,n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n,n**2, aling="center", width=0.5, alpha= 0.5)
axes[2].set_title("bar")

axes[3].fill_between(x,x**2,x**3, color="green", alpha=0.5)
axes[3].set_title("fill_between");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     116     try:
# --> 117         num = operator.index(num)
#     118     except TypeError:
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-38384e331eb1> in <module>()
# ----> 1 xx = np.linspace(-0,75,1.,100)
#       2 n= np.array([0,1,2,3,4,5])
#       3
#       4 fig,axes = plt.subplots(1,4,figsize=(12,3))
#       5
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     119         raise TypeError(
#     120             "object of type {} cannot be safely interpreted as an integer."
# --> 121                 .format(type(num)))
#     122
#     123     if num < 0:
#
# TypeError: object of type <class 'float'> cannot be safely interpreted as an integer.
